# %% [markdown]
# Name : Preeti Eknath Kharmale
#
# Rollno : PB 71

# %% [markdown]
# ## Linear Regression

# %%
# GPA BASED PREDICTION ON SAT SCORE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/1.01. Simple linear regression.csv")
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
x = data.iloc[:,:-1].values

# %%
x
# Out:
# array([[1714],
#        [1664],
#        [1760],
#        [1685],
#        [1693],
#        [1670],
#        [1764],
#        [1764],
#        [1792],
#        [1850],
#        [1735],
#        [1775],
#        [1735],
#        [1712],
#        [1773],
#        [1872],
#        [1755],
#        [1674],
#        [1842],
#        [1786],
#        [1761],
#        [1722],
#        [1663],
#        [1687],
#        [1974],
#        [1826],
#        [1787],
#        [1821],
#        [2020],
#        [1794],
#        [1769],
#        [1934],
#        [1775],
#        [1855],
#        [1880],
#        [1849],
#        [1808],
#        [1954],
#        [1777],
#        [1831],
#        [1865],
#        [1850],
#        [1966],
#        [1702],
#        [1990],
#        [1925],
#        [1824],
#        [1956],
#        [1857],
#        [1979],
#        [1802],
#        [1855],
#        [1907],
#        [1634],
#        [1879],
#        [1887],
#        [1730],
#        [1953],
# ...

# %%
y = data.iloc[:,-1].values

# %%
y
# Out:
# array([2.4 , 2.52, 2.54, 2.74, 2.83, 2.91, 3.  , 3.  , 3.01, 3.01, 3.02,
#        3.07, 3.08, 3.08, 3.12, 3.17, 3.17, 3.17, 3.17, 3.19, 3.19, 3.19,
#        3.2 , 3.21, 3.24, 3.28, 3.28, 3.28, 3.28, 3.28, 3.28, 3.28, 3.29,
#        3.29, 3.29, 3.31, 3.32, 3.34, 3.37, 3.37, 3.37, 3.38, 3.38, 3.39,
#        3.39, 3.4 , 3.4 , 3.4 , 3.41, 3.41, 3.41, 3.42, 3.42, 3.42, 3.44,
#        3.47, 3.47, 3.47, 3.47, 3.48, 3.49, 3.49, 3.5 , 3.51, 3.51, 3.52,
#        3.52, 3.54, 3.58, 3.58, 3.59, 3.59, 3.6 , 3.6 , 3.61, 3.62, 3.64,
#        3.65, 3.71, 3.71, 3.71, 3.73, 3.76, 3.81])

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test= train_test_split(x,y,test_size =0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
classifier = LinearRegression()

# %%
classifier.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
classifier.coef_                # coef=  b1     - depends on the independent feature                                   y=b0 + b1x
# Out:
# array([0.00171033])

# %%
classifier.intercept_           # intercept = b0                - there is always one
# Out:
# 0.16586478019104378

# %%
# Check the accuracy
classifier.score(X_train,Y_train)
# Out:
# 0.42509483676777093

# %%
# mean sqr error , mean absolute and r2 score is used , ranges from 0-1 .
# precision , recall, f1 score is not used to measure in regression

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([3.19143271, 3.35562407, 3.07684082, 3.24787349, 3.01013808,
#        3.37956865, 3.17603977, 3.12472997, 3.22221859, 3.23077023,
#        3.46850564, 3.09394409, 3.32996917, 3.62072471, 3.16748814,
#        3.2803697 , 3.61217308])

# %%
df1 = pd.DataFrame({'Actual': Y_test.flatten(), 'Predicted': y_pred.flatten()})
df1
# Out:
#     Actual  Predicted
# 0     3.28   3.191433
# 1     3.37   3.355624
# 2     3.39   3.076841
# 3     3.41   3.247873
# 4     3.20   3.010138
# 5     3.44   3.379569
# 6     2.54   3.176040
# 7     3.47   3.124730
# 8     3.28   3.222219
# 9     3.01   3.230770
# 10    3.58   3.468506
# 11    3.08   3.093944
# 12    3.52   3.329969
# 13    3.65   3.620725
# 14    3.17   3.167488
# 15    3.28   3.280370
# 16    3.62   3.612173

# %%
# Data Visualization
plt.plot(X_test,Y_test,'o')
plt.plot(X_test,y_pred)
plt.show()

# dots passing through the line is the predicited data
# dots above the line are the actual data

# %% [markdown]
# # Multiple Linear Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing

# %%
df = pd.read_csv("/content/Real-estate1.csv")
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.drop('No', inplace = True, axis = 1)
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
df.tail()
# Out:
#      X1 transaction date  X2 house age  \
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# 411     24.97923     121.53986                        40.6
# ...

# %%
 # dependent var = Y house price of unit area , independent var- rest all 6

# %%
# creating feature variables
X = df.drop('Y house price of unit area' , axis =1 )
y = df['Y house price of unit area']

# %%
X
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
# creating the train test sets

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state = 101)

# %%
# creating regression model
model = LinearRegression()

# fitting the model
model.fit(X_train,y_train)

# making predicitions
predictions = model.predict(X_test)

# %%
# Model Evaluation

print(
    'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
     'mean_absolute_error : ', mean_absolute_error(y_test, predictions))

# more value - bad model
# Out:
# mean_squared_error :  46.21179783492909
# mean_absolute_error :  5.392293684756193

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, predictions)

print("r2 score is :  ", score)              # value from 0 to 1 , more value - good model
# Out:
# r2 score is :   0.6509058479987158

# %%
model.coef_                # coef=  b1     - depends on the independent feature - so 6                                  y=b0 + b1x

# coeff value with less value can be ommited
# shrinking the coeff to avoid overfit - for this rigg and lasso is used
# Out:
# array([ 4.83926101e+00, -2.74749120e-01, -4.18860818e-03,  1.18123112e+00,
#         2.42384317e+02,  2.33991349e+01])

# %%
model.intercept_
# Out:
# -18595.05503451969

# %% [markdown]
# # Lasso Regression

# %%
# shrinking the coeff to avoid overfit

# %%
import pandas as pd
import numpy as np

mt = pd.read_csv("/content/mtcars.csv")
mt
# Out:
#            manufacturer   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mt = mt.drop(columns = 'manufacturer', axis = 1)

# %%
x = mt.drop(columns = 'hp', axis = 1)
y = mt['hp']

# %%
# splitting the data into train test

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3 , random_state = 4)

# %%
# fitting the data into the model

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
lr.coef_
# Out:
# array([ -9.06899346,  10.16348563,   0.60727233,   5.22543962,
#        -73.5857895 ,   6.1206149 ,  20.89008436,  -2.51710243,
#         29.05394213,  15.80064161])

# %%
lr.intercept_
# Out:
# 67.07834421028483

# %%
from sklearn.metrics import r2_score
x_pred_test = lr.predict(x_test)
r2_score(y_test,x_pred_test)
# Out:
# 0.5481509214699449

# %%
# LASSO
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(x_train,y_train)
# Out:
# Lasso()

# %%
lasso.coef_
# Out:
# array([ -4.38467504,   0.        ,   0.420876  ,  -0.        ,
#        -31.87872877,  -0.        ,   0.26387533,  -0.        ,
#          0.45416867,  20.99506847])

# %%
lasso.intercept_
# Out:
# 172.2345640074913

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge
clf = Ridge(alpha = 2)                      #alpha = 0.001 , 0.005, 1, 2,3 ,4,5
clf.fit(x_train,y_train)
# Out:
# Ridge(alpha=2)

# %%
x_pred_ridge_test = clf.predict(x_test)
r2_score(y_test, x_pred_ridge_test)
# Out:
# 0.8123640542820444

# %%
clf.coef_
# Out:
# array([ -3.62140671,   5.01993262,   0.35600289,   1.64641657,
#        -16.31429663,  -2.77647922,   7.76568037,   2.42288773,
#          9.05272122,  16.13573515])

# %%
clf.intercept_
# Out:
# 113.2153303891952

# %%
# alpha = 5

clf = Ridge(alpha = 5)                      #alpha = 0.001 , 0.005, 1, 2,3 ,4,5
clf.fit(x_train,y_train)
x_pred_ridge_test = clf.predict(x_test)
r2_score(y_test, x_pred_ridge_test)
# Out:
# 0.8093021381244343

# %%
# alpha = 4

clf = Ridge(alpha = 4)                      #alpha = 0.001 , 0.005, 1, 2,3 ,4,5
clf.fit(x_train,y_train)
x_pred_ridge_test = clf.predict(x_test)
r2_score(y_test, x_pred_ridge_test)
# Out:
# 0.8107382082422834
